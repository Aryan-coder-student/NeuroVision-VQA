# %%
# !pip install datasets
from datasets import load_dataset
ds = load_dataset("flaviagiammarino/vqa-rad",cache_dir="../data/bronze")
# Out:
# Downloading data:   0%|          | 0.00/24.2M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/10.3M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1793 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/451 [00:00<?, ? examples/s]

# %%
ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'question', 'answer'],
#         num_rows: 1793
#     })
#     test: Dataset({
#         features: ['image', 'question', 'answer'],
#         num_rows: 451
#     })
# })

# %%
ds["train"][0]["image"]
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=566x555>

# %%
ds["train"][5]["question"] , ds["train"][5]["answer"]
# Out:
# ('what is the condition of the patient', 'blind loop syndrome')

# %%
import os
import requests
from transformers import BlipProcessor, BlipForQuestionAnswering
from datasets import load_dataset
import torch
from PIL import Image
from torch.utils.data import DataLoader
from tqdm import tqdm
import pickle

model = BlipForQuestionAnswering.from_pretrained("Salesforce/blip-vqa-base")
processor = BlipProcessor.from_pretrained("Salesforce/blip-vqa-base")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

torch.cuda.empty_cache()
torch.manual_seed(42)

class VQADataset(torch.utils.data.Dataset):
    """VQA (v2) dataset."""
    def __init__(self, dataset, processor):
        self.dataset = dataset
        self.processor = processor

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        # get image + text
        question = self.dataset[idx]['question']
        answer = self.dataset[idx]['answer']
        image = self.dataset[idx]['image']
        image = image.convert("RGB")
        text = question

        encoding = self.processor(image, text, padding="max_length", truncation=True, return_tensors="pt")
        labels = self.processor.tokenizer.encode(
            answer, max_length=8, padding="max_length", truncation=True,pad_to_max_length=True, return_tensors='pt'
        )
        encoding["labels"] = labels
        for k, v in encoding.items():
            encoding[k] = v.squeeze()
        return encoding

# %%
training_dataset = ds["train"]
valid_dataset = ds["test"]
print("Training sets: {} - Validating set: {}".format(len(training_dataset), len(valid_dataset)))

train_dataset = VQADataset(dataset=training_dataset,
                          processor=processor)
valid_dataset = VQADataset(dataset=valid_dataset,
                          processor=processor)
# Out:
# Training sets: 1793 - Validating set: 451

# %% [markdown]
# # Saving The Process dataset to reduce trainiq time

# %%
import pickle
import os

# Define the path where you want to save the processed data
save_dir = "../data/silver"
os.makedirs(save_dir, exist_ok=True)

# Save the training and validation datasets
with open(os.path.join(save_dir, "train_dataset.pkl"), "wb") as f:
    pickle.dump(train_dataset, f)

with open(os.path.join(save_dir, "valid_dataset.pkl"), "wb") as f:
    pickle.dump(valid_dataset, f)

print("Processed data saved to ../data/silver")
# Out:
# Processed data saved to ../data/silver

# %%
if os.path.exists(os.path.join(save_dir, "train_dataset.pkl")) and os.path.exists(os.path.join(save_dir, "valid_dataset.pkl")):
    with open(os.path.join(save_dir, "train_dataset.pkl"), "rb") as f:
        train_dataset = pickle.load(f)

    with open(os.path.join(save_dir, "valid_dataset.pkl"), "rb") as f:
        valid_dataset = pickle.load(f)
    print("Loaded processed data from ../data/silver")
# Out:
# Loaded processed data from ../data/silver

# %%
batch_size = 4
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, pin_memory=True)
valid_dataloader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False, pin_memory=True)

# %%
len(train_dataset)
# Out:
# 1793

# %%
# !pip install nltk
# import nltk
# nltk.download('all')

# %% [markdown]
# # Use the train_dataset.pkl and validation_dataset.pkl from the data directory to train the model

# %%
from transformers import get_linear_schedule_with_warmup
from nltk.translate.bleu_score import sentence_bleu
from nltk.tokenize import word_tokenize
        
num_epochs = 100
patience = 10
min_bleu_score = 0
early_stopping_hook = 0
tracking_information = []
gradient_accumulation_steps = 4  
optimizer = torch.optim.AdamW(model.parameters(), lr=4e-5, weight_decay=1e-4)
total_steps = len(train_dataloader) * num_epochs
warmup_steps = total_steps // 10
scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=warmup_steps, num_training_steps=total_steps)
scaler = torch.amp.GradScaler('cuda')

# %%
for epoch in range(num_epochs):
    model.train()
    epoch_loss = 0

    for step, batch in enumerate(tqdm(train_dataloader, desc=f"Epoch {epoch+1} Training")):
        input_ids = batch.pop('input_ids').to(device)
        pixel_values = batch.pop('pixel_values').to(device)
        attention_mask = batch.pop('attention_mask').to(device)
        labels = batch.pop('labels').to(device)

        with torch.amp.autocast('cuda', dtype=torch.float16):
            outputs = model(input_ids=input_ids, pixel_values=pixel_values, attention_mask=attention_mask, labels=labels)
            loss = outputs.loss / gradient_accumulation_steps  # Normalize loss

        scaler.scale(loss).backward()

        if (step + 1) % gradient_accumulation_steps == 0 or (step + 1) == len(train_dataloader):
            scaler.unscale_(optimizer)  # Unscales gradients before clipping
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)  # Gradient clipping
            scaler.step(optimizer)
            scaler.update()
            optimizer.zero_grad()

        epoch_loss += loss.item() * gradient_accumulation_steps

    # Validation Loop
    model.eval()
    eval_loss = 0
    bleu_scores = []
    
    with torch.no_grad():
        for batch in tqdm(valid_dataloader, desc=f"Epoch {epoch+1} Validating"):
            input_ids = batch.pop('input_ids').to(device)
            pixel_values = batch.pop('pixel_values').to(device)
            attention_mask = batch.pop('attention_mask').to(device)
            labels = batch.pop('labels').to(device)
    
            # Forward pass
            with torch.amp.autocast('cuda', dtype=torch.float16):
                outputs = model(input_ids=input_ids, pixel_values=pixel_values, attention_mask=attention_mask, labels=labels)
                eval_loss += outputs.loss.item()
    
            # Generate predictions using model.generate()
            generated_ids = model.generate(input_ids=input_ids,pixel_values=pixel_values, attention_mask=attention_mask, max_length=8)
            predictions = processor.tokenizer.batch_decode(generated_ids, skip_special_tokens=True)
    
            # Decode references (true answers) from labels
            references = processor.tokenizer.batch_decode(labels, skip_special_tokens=True)
    
            # Calculate BLEU score for each prediction-reference pair
            for pred, ref in zip(predictions, references):
                bleu_scores.append(sentence_bleu([word_tokenize(ref)], word_tokenize(pred)))
    
    # Calculate averages
    avg_train_loss = epoch_loss / len(train_dataloader)
    avg_eval_loss = eval_loss / len(valid_dataloader)
    avg_bleu_score = sum(bleu_scores) / len(bleu_scores)
    tracking_information.append((avg_train_loss, avg_eval_loss, avg_bleu_score, optimizer.param_groups[0]["lr"]))
    
    print(f"Epoch {epoch+1} - Train Loss: {avg_train_loss:.4f} - Eval Loss: {avg_eval_loss:.4f} - BLEU Score: {avg_bleu_score:.4f} - LR: {optimizer.param_groups[0]['lr']}")
        
        # Save model if BLEU improves
    if avg_bleu_score >= min_bleu_score:
        model.save_pretrained("Model/blip-saved-model", from_pt=True)
        print(f"Model improved (BLEU: {avg_bleu_score:.4f})! Saved to Model/blip-saved-model.")
        min_bleu_score = avg_bleu_score
        early_stopping_hook = 0
    else:
        early_stopping_hook += 1
        if early_stopping_hook > patience:
            print("Early stopping triggered.")
            break
    
    scheduler.step()  # Update learning rate
# Out:
# Epoch 1 Training:   0%|          | 0/449 [00:00<?, ?it/s]We strongly recommend passing in an `attention_mask` since your input_ids may be padded. See https://huggingface.co/docs/transformers/troubleshooting#incorrect-output-when-padding-tokens-arent-masked.
# Epoch 1 Training:   1%|          | 4/449 [01:21<2:31:20, 20.41s/it]
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[21], line 12
#       9 labels = batch.pop('labels').to(device)
#      11 with torch.amp.autocast('cuda', dtype=torch.float16):
# ---> 12     outputs = model(input_ids=input_ids, pixel_values=pixel_values, attention_mask=attention_mask, labels=labels)
#      13     loss = outputs.loss / gradient_accumulation_steps  # Normalize loss
#      15 scaler.scale(loss).backward()
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\models\blip\modeling_blip.py:1311, in BlipForQuestionAnswering.forward(self, input_ids, pixel_values, decoder_input_ids, decoder_attention_mask, attention_mask, output_attentions, output_hidden_states, labels, return_dict, interpolate_pos_encoding)
#    1308 image_embeds = vision_outputs[0]
#    1309 image_attention_mask = torch.ones(image_embeds.size()[:-1], dtype=torch.long)
# -> 1311 question_embeds = self.text_encoder(
#    1312     input_ids=input_ids,
#    1313     attention_mask=attention_mask,
#    1314     encoder_hidden_states=image_embeds,
#    1315     encoder_attention_mask=image_attention_mask,
#    1316     return_dict=return_dict,
#    1317 )
#    1319 if labels is not None and decoder_input_ids is None:
#    1320     # labels are already shifted right, see: https://github.com/huggingface/transformers/pull/23153
#    1321     decoder_input_ids = labels
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\models\blip\modeling_blip_text.py:783, in BlipTextModel.forward(self, input_ids, attention_mask, position_ids, head_mask, inputs_embeds, encoder_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict, is_decoder)
#     780 else:
#     781     embedding_output = encoder_embeds
# --> 783 encoder_outputs = self.encoder(
#     784     embedding_output,
#     785     attention_mask=extended_attention_mask,
#     786     head_mask=head_mask,
#     787     encoder_hidden_states=encoder_hidden_states,
#     788     encoder_attention_mask=encoder_extended_attention_mask,
#     789     past_key_values=past_key_values,
#     790     use_cache=use_cache,
#     791     output_attentions=output_attentions,
#     792     output_hidden_states=output_hidden_states,
#     793     return_dict=return_dict,
#     794 )
#     795 sequence_output = encoder_outputs[0]
#     796 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\models\blip\modeling_blip_text.py:437, in BlipTextEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     426     layer_outputs = self._gradient_checkpointing_func(
#     427         layer_module.__call__,
#     428         hidden_states,
#    (...)
#     434         output_attentions,
#     435     )
#     436 else:
# --> 437     layer_outputs = layer_module(
#     438         hidden_states,
#     439         attention_mask,
#     440         layer_head_mask,
#     441         encoder_hidden_states,
#     442         encoder_attention_mask,
#     443         past_key_value,
#     444         output_attentions,
#     445     )
#     447 hidden_states = layer_outputs[0]
#     448 if use_cache:
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\models\blip\modeling_blip_text.py:359, in BlipTextLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     356 present_key_value = self_attention_outputs[-1]
#     358 if encoder_hidden_states is not None:
# --> 359     cross_attention_outputs = self.crossattention(
#     360         attention_output,
#     361         attention_mask,
#     362         head_mask,
#     363         encoder_hidden_states,
#     364         encoder_attention_mask,
#     365         output_attentions=output_attentions,
#     366     )
#     367     attention_output = cross_attention_outputs[0]
#     368     outputs = outputs + cross_attention_outputs[1:-1]  # add cross attentions if we output attention weights
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\models\blip\modeling_blip_text.py:276, in BlipTextAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     266 def forward(
#     267     self,
#     268     hidden_states: torch.Tensor,
#    (...)
#     274     output_attentions: Optional[bool] = False,
#     275 ) -> Tuple[torch.Tensor]:
# --> 276     self_outputs = self.self(
#     277         hidden_states,
#     278         attention_mask,
#     279         head_mask,
#     280         encoder_hidden_states,
#     281         encoder_attention_mask,
#     282         past_key_value,
#     283         output_attentions,
#     284     )
#     285     attention_output = self.output(self_outputs[0], hidden_states)
#     286     outputs = (attention_output,) + self_outputs[1:]  # add attentions if we output them
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\models\blip\modeling_blip_text.py:213, in BlipTextSelfAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     210 if head_mask is not None:
#     211     attention_probs_dropped = attention_probs_dropped * head_mask
# --> 213 context_layer = torch.matmul(attention_probs_dropped, value_layer)
#     215 context_layer = context_layer.permute(0, 2, 1, 3).contiguous()
#     216 new_context_layer_shape = context_layer.size()[:-2] + (self.all_head_size,)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 28.00 MiB. GPU 0 has a total capacity of 4.00 GiB of which 0 bytes is free. Of the allocated memory 10.41 GiB is allocated by PyTorch, and 353.48 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
model.save_pretrained(f"Model/{epoch}-last-blip-saved-model", from_pt=True)
print(f"Model improved (BLEU: {avg_bleu_score:.4f})! Saved to Model/blip-saved-model.")
# Out:
# Model improved (BLEU: 0.0000)! Saved to Model/blip-saved-model.

# %%
import matplotlib.pyplot as plt

# %%
pickle.dump(tracking_information, open("tracking_information.pkl", "wb"))
train_losses, eval_losses, bleu_scores, lrs = zip(*tracking_information)
epochs = range(1, len(train_losses) + 1)
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(epochs, train_losses, label="Train Loss")
plt.plot(epochs, eval_losses, label="Eval Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training and Evaluation Loss")
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(epochs, bleu_scores, label="BLEU Score", color="green")
plt.xlabel("Epochs")
plt.ylabel("BLEU Score")
plt.title("BLEU Score Over Epochs")
plt.legend()
plt.tight_layout()
plt.savefig("training_progress.png")
plt.show()

print("Fine-tuning process completed!")

# %%
def compare_output_model(original_model_path, finetuned_model_path,image,question,device):
    pre_trained_model = BlipForQuestionAnswering.from_pretrained(original_model_path).to(device)
    fine_tuned_model = BlipForQuestionAnswering.from_pretrained(finetuned_model_path).to(device)
    image = image.convert('RGB')
    inputs = processor(image, question, return_tensors="pt").to(device)
    fine_tuned_output = fine_tuned_model.generate(**inputs)
    pre_trained_output = pre_trained_model.generate(**inputs)
    fine_tuned_answer = processor.tokenizer.decode(fine_tuned_output[0], skip_special_tokens=True)
    pre_trained_answer = processor.tokenizer.decode(pre_trained_output[0], skip_special_tokens=True)
    print("Question : ",question)
    print('Model Answer : ',pre_trained_answer)
    print('Finetuned Answer : ',fine_tuned_answer)

# %%
sample_index = 21
sample_image = ds["train"][sample_index]['image']
sample_question = ds["train"][sample_index]['question']
compare_output_model(
    original_model_path="Salesforce/blip-vqa-base",
    finetuned_model_path="Model/14-last-blip-saved-model",
    image=sample_image,
    question=sample_question,
    device=device
)
print("Original Answer: " , ds["train"][sample_index]['answer'])
ds["train"][sample_index]['image']
# Out:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\generation\utils.py:1375: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Question :  what are the characteristics of the mass?
# Model Answer :  white
# Finetuned Answer :  triceps
# Original Answer:  isointense
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x473>
